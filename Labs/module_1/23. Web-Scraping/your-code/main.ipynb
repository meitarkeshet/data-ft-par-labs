# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
page = requests.get(url) # download the website page using "get" into a var called 'page'
page.status_code # 200 indicates sucsses 
#page.content
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser') #
print(soup.prettify()) # use "prettify" to show the contents nicely
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-b133e7e2e714bf9d6fe36c44e8979d76.css" integrity="sha512-sTPn4ucUv51v42xE6Jeddjc8xD4F5Qzs3PUlX4tko79zmOo+vjkqOGBNcXNtGkfjoFSRmxAzx3X25ApYG0NY1w==" media="all" rel="stylesheet">
# ...

# %%
names = soup.select("div:nth-child(3) > div:nth-child(1) > div:nth-child(1) > h1:nth-child(1) > a:nth-child(1)")
#the css location : 
#pa-frenck > div.d-sm-flex.flex-auto > div.col-sm-8.d-md-flex > div:nth-child(1) > h1
print(names)
#names.get_text()
#print(names)
# Out:
# [<a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":195327,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="555942f6cd3662c48ba480f22a7879a37d3e1a89beb3fa5d8221b0fd6c84b717" href="/frenck">
#             Franck Nijhof
# </a>, <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":1293565,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b7ab7a901862ba6ea8f73050f585f91fbf698e76de716f83365f4224521453f" href="/amaurymartiny">
#             Amaury
# ...

# %%
names = [i.text for i in names]
print(names)
# Out:
# ['\n            Franck Nijhof\n', '\n            Amaury\n', '\n            PySimpleGUI\n', '\n            Pariente Manuel\n', '\n            David Fahlander\n', '\n            David Peter\n', '\n            Stefan Prodan\n', '\n            Ariel Mashraki\n', '\n            Francois Zaninotto\n', '\n            Juliette\n', '\n            Luís Cobucci\n', '\n            Vincenzo Chianese\n', '\n            Stefan Karpinski\n', '\n            Remi Rousselet\n', '\n            Mike Penz\n', '\n            Sebastián Ramírez\n', '\n            Li Haoyi\n', '\n            Matthias Urhahn\n', '\n            Brian Flad\n', '\n            Will McGugan\n', '\n            Romain Rigaux\n', '\n            Dries Vints\n', '\n            Jason Quense\n', '\n            James Brooks\n', '\n            MinJae Kwon\n']

# %%
names = [i.replace('\n', '').strip() for i in names]
#type(names)
#names_clnd = str(names)
#names_clnd = na.split("\n")

# %%
#let's do the same thing for the aliases
#alias = soup.select("div.d-sm-flex.flex-auto > div.col-sm-8.d-md-flex > div:nth-child(1) > p > a")
#alias = [i.text for i in alias]
#alias = [i.replace('\n', '').strip() for i in alias]
#merged =[(names[i], alias[i]) for i in range(0, len(names))] 
[i.text.strip() + ' '+ i.get('href')  for i in names]
# Out:
# [<a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":195327,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="555942f6cd3662c48ba480f22a7879a37d3e1a89beb3fa5d8221b0fd6c84b717" href="/frenck">
#              Franck Nijhof
#  </a>,
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":1293565,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b7ab7a901862ba6ea8f73050f585f91fbf698e76de716f83365f4224521453f" href="/amaurymartiny">
#              Amaury
#  </a>,
# ...

# %%
print(merged)
# Out:
# [('Franck Nijhof', 'frenck'), ('Amaury', 'amaurymartiny'), ('PySimpleGUI', 'PySimpleGUI'), ('Pariente Manuel', 'mpariente'), ('David Fahlander', 'dfahlander'), ('David Peter', 'sharkdp'), ('Stefan Prodan', 'stefanprodan'), ('Ariel Mashraki', 'a8m'), ('Francois Zaninotto', 'fzaninotto'), ('Juliette', 'jrfnl'), ('Luís Cobucci', 'lcobucci'), ('Vincenzo Chianese', 'XVincentX'), ('Stefan Karpinski', 'StefanKarpinski'), ('Remi Rousselet', 'rrousselGit'), ('Mike Penz', 'mikepenz'), ('Sebastián Ramírez', 'tiangolo'), ('Li Haoyi', 'lihaoyi'), ('Matthias Urhahn', 'd4rken'), ('Brian Flad', 'bflad'), ('Will McGugan', 'willmcgugan'), ('Romain Rigaux', 'romainr'), ('Dries Vints', 'driesvints'), ('Jason Quense', 'jquense'), ('James Brooks', 'jbrooksuk'), ('MinJae Kwon', 'mingrammer')]

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
names = soup.select("h1.h3 a")
names = [" ".join(i.text.strip().split()) for i in names]
names
# Out:
# ['TheAlgorithms / Python',
#  'NathanUA / U-2-Net',
#  'RangiLyu / nanodet',
#  'shreyashankar / create-ml-app',
#  'sting8k / BurpSuite_403Bypasser',
#  'JaidedAI / EasyOCR',
#  'cloudera / hue',
#  'bregman-arie / devops-exercises',
#  'willmcgugan / rich',
#  'dkkocab / WebSiteBot_PS5',
#  'huggingface / transformers',
#  'drivendata / cookiecutter-data-science',
#  'intelowlproject / IntelOwl',
#  'chris-lovejoy / YouTube-video-finder',
#  'MrMimic / data-scientist-roadmap',
#  'yiranran / APDrawingGAN',
#  'kangvcar / InfoSpider',
#  'minimaxir / big-list-of-naughty-strings',
#  'nvbn / thefuck',
#  'zongyi-li / fourier_neural_operator',
#  'trekhleb / learn-python',
#  'sammchardy / python-binance',
#  'mingrammer / diagrams',
#  'google / flax',
#  'ultralytics / yolov5']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-ac526c16b3f9> in <module>
# ----> 1 merged =[(names[i], description[i]) for i in range(0, len(names))]
#
# <ipython-input-102-ac526c16b3f9> in <listcomp>(.0)
# ----> 1 merged =[(names[i], description[i]) for i in range(0, len(names))]
#
# NameError: name 'description' is not defined

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser')

# %%
images = soup.select("a.image")

images
# Out:
# [<a class="image" href="/wiki/File:Walt_Disney_1946.JPG"><img alt="Walt Disney 1946.JPG" data-file-height="675" data-file-width="450" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/330px-Walt_Disney_1946.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/440px-Walt_Disney_1946.JPG 2x" width="220"/></a>,
# ...

# %%
images = soup.select("div.thumbinner img")
images = [i["src"].strip("//") for i in images]
images
# Out:
# ['upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
links = soup.select("a:visited, a:link")
#names = [" ".join(i.text.strip().split()) for i in names]
links
#[i.text.strip() + ' '+ i.get('href')  for i in links]
[i.get('href') for i in links]
# Out:
# ['#mw-head',
#  '#searchInput',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '/wiki/Pythons',
#  '/wiki/Python_(genus)',
#  '#Computing',
#  '#People',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#Other_uses',
#  '#See_also',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
#  '/w/index.php?title=Python&action=edit&section=2',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/wiki/Python_Anghelo',
#  '/w/index.php?title=Python&action=edit&section=3',
#  '/wiki/Python_(Efteling)',
#  '/wiki/Python_(Busch_Gardens_Tampa_Bay)',
#  '/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)',
#  '/w/index.php?title=Python&action=edit&section=4',
#  '/wiki/Python_(automobile_maker)',
#  '/wiki/Python_(Ford_prototype)',
#  '/w/index.php?title=Python&action=edit&section=5',
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
changed = soup.select(".usctitlechanged")
changed
[i.text.strip() for i in changed]
# Out:
# ['Title 7 - Agriculture',
#  'Title 11 - Bankruptcy ٭',
#  'Title 13 - Census ٭',
#  'Title 14 - Coast Guard ٭',
#  'Title 15 - Commerce and Trade',
#  'Title 16 - Conservation',
#  'Title 21 - Food and Drugs',
#  'Title 24 - Hospitals and Asylums',
#  'Title 27 - Intoxicating Liquors',
#  'Title 32 - National Guard ٭',
#  'Title 33 - Navigation and Navigable Waters',
#  'Title 34 - Crime Control and Law Enforcement',
#  'Title 36 - Patriotic and National Observances, Ceremonies, and Organizations ٭',
#  "Title 38 - Veterans' Benefits ٭",
#  'Title 42 - The Public Health and Welfare',
#  'Title 45 - Railroads',
#  'Title 49 - Transportation ٭',
#  'Title 54 - National Park Service and Related Programs ٭']

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
changed = soup.select(".title")
changed
[i.text.strip() for i in changed]
# Out:
# ['Most Wanted',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'EUGENE PALMER',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'YASER ABDEL SAID']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
earthquakes_20 = soup.select(".tb_region, .ago")

tables = soup.select(".tb_region, .ago")

earthquakes_20
#earthquakes_20_df = pd.DataFrame(earthquakes_20)
#earthquakes_20_df
#[i.text.strip() for i in changed]

#table = soup.find('table', attrs={'class':'subs noBorders evenRows'})
#table_rows = tables.find_all('tr')
# Out:
# [<i class="ago" id="ago0">21min ago</i>,
#  <td class="tb_region" id="reg0"> JUJUY, ARGENTINA</td>,
#  <i class="ago" id="ago1">30min ago</i>,
#  <td class="tb_region" id="reg1"> DODECANESE ISLANDS, GREECE</td>,
#  <i class="ago" id="ago2">1hr 23min ago</i>,
#  <td class="tb_region" id="reg2"> WESTERN TURKEY</td>,
#  <i class="ago" id="ago3">1hr 26min ago</i>,
#  <td class="tb_region" id="reg3"> PYRENEES</td>,
#  <i class="ago" id="ago4">1hr 40min ago</i>,
#  <td class="tb_region" id="reg4"> CENTRAL TURKEY</td>,
#  <i class="ago" id="ago5">1hr 45min ago</i>,
#  <td class="tb_region" id="reg5"> HALMAHERA, INDONESIA</td>,
#  <i class="ago" id="ago6">2hr 26min ago</i>,
#  <td class="tb_region" id="reg6"> EASTERN TURKEY</td>,
#  <i class="ago" id="ago7">2hr 27min ago</i>,
#  <td class="tb_region" id="reg7"> OFF E. COAST OF N. ISLAND, N.Z.</td>,
#  <i class="ago" id="ago8">2hr 35min ago</i>,
#  <td class="tb_region" id="reg8"> WESTERN TEXAS</td>,
# ...

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
url = 'https://twitter.com/'
try:
    user_handle = input("User input?\n")
    url = url+user_handle # add the user intput
    print(url)
    page = requests.get(url)# download the website page using "get" into a var called 'page'
except:
    print(f'Error status: {page.status_code}')
else:
    print(f'Page status: {page.status_code}')
# Out:
# User input?
# tryguys
# https://twitter.com/tryguys
# Page status: 200

# %%
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
#tweets_num = soup.select("div.css-1dbjc4n.r-16y2uox.r-1wbh5a2.r-1pi2tsx.r-1777fci > div > div")
#print(tweets_num)
#print (type(soup))
import re 
str_soup = str(soup)
print(str_soup)
#tweets_num = re.findall("Tweets",str_soup) 
#print(tweets_num)

if tweets_num == []:
    print("Either 0 tweets OR blocked user")
else:
    print("horray!")
#[i.text.strip() for i in changed]
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
# <link href="//abs.twimg.com" rel="preconnect"/>
# <link href="//api.twitter.com" rel="preconnect"/>
# <link href="//pbs.twimg.com" rel="preconnect"/>
# <link href="//t.co" rel="preconnect"/>
# <link href="//video.twimg.com" rel="preconnect"/>
# <link href="//abs.twimg.com" rel="dns-prefetch"/>
# <link href="//api.twitter.com" rel="dns-prefetch"/>
# <link href="//pbs.twimg.com" rel="dns-prefetch"/>
# <link href="//t.co" rel="dns-prefetch"/>
# <link href="//video.twimg.com" rel="dns-prefetch"/>
# <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/client-web-legacy/polyfills.e49ae9f5.js" nonce="ZmVjZjVmYzktNWJiZS00YWUwLWExNzAtNjA3NzAzYTZjNGMy" rel="preload"/>
# ...

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# This is the url you will scrape in this exercise
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #

center = soup.select("[lang]")

#[i.get('strong') for i in center]
center = [i.text for i in center][1:]
center = [i for i in center if re.search("\n", i)]
lang = [ i.replace("\n","") for i in center ]
#lang = lang.match
lang
# until a string
# Out:
# ['English6\xa0195\xa0000+ articles',
#  'Español1\xa0641\xa0000+ artículos',
#  '日本語1\xa0239\xa0000+ 記事',
#  'Deutsch2\xa0503\xa0000+ Artikel',
#  'Русский1\xa0678\xa0000+ статей',
#  'Français2\xa0270\xa0000+ articles',
#  'Italiano1\xa0652\xa0000+ voci',
#  '中文1\xa0159\xa0000+ 條目',
#  'Português1\xa0047\xa0000+ artigos',
#  'Polski1\xa0439\xa0000+ haseł']

# %%
lang_ex = [re.split('[0-9]', str(i))[0] for i in lang]
lang_ex
# Out:
# ['English',
#  'Español',
#  '日本語',
#  'Deutsch',
#  'Русский',
#  'Français',
#  'Italiano',
#  '中文',
#  'Português',
#  'Polski']

# %%
lang
lang_num = ["".join(re.findall(r'[0-9]', str(i))) for i in lang]
merged =[(lang_ex[i], lang_num[i]) for i in range(0, len(lang_num))] 
merged
# Out:
# [('English', '6195000'),
#  ('Español', '1641000'),
#  ('日本語', '1239000'),
#  ('Deutsch', '2503000'),
#  ('Русский', '1678000'),
#  ('Français', '2270000'),
#  ('Italiano', '1652000'),
#  ('中文', '1159000'),
#  ('Português', '1047000'),
#  ('Polski', '1439000')]

# %% [markdown]
# ###### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# This is the url you will scrape in this exercise
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
kinds = soup.select("h3")
kinds = [i.text for i in kinds]

kinds
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# This is the url you will scrape in this exercise
page = requests.get(url) # download the website page using "get" into a var called 'page'
#page.status_code # 200 indicates sucsses 
soup = BeautifulSoup(page.content, 'html.parser') #
#print(soup.prettify()) # use "prettify" to show the contents nicely
table = soup.select("table:nth-of-type(3) ")
#columns = soup.select("th")
#columns = [i.text for i in columns]
print(table)
df = pd.read_html(table)

#columns = tables.select("th")
# Out:
# [<table class="wikitable sortable">
# <caption>Top languages by population per <i>Nationalencyklopedin</i>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Language
# </th>
# <th data-sort-type="number">Native<br/>speakers<br/>in millions<br/>2007 (2010)
# </th>
# <th>Percentage<br/>of world<br/>population<br/>(2007)
# </th></tr>
# <tr>
# <td>1</td>
# <td><a href="/wiki/Mandarin_Chinese" title="Mandarin Chinese">Mandarin</a> (entire branch)</td>
# <td>935 (955)</td>
# <td>14.1%
# </td></tr>
# <tr>
# <td>2</td>
# <td><a href="/wiki/Spanish_language" title="Spanish language">Spanish</a></td>
# <td>390 (405)</td>
# <td>5.85%
# </td></tr>
# <tr>
# <td>3</td>
# <td><a href="/wiki/English_language" title="English language">English</a></td>
# <td>365 (360)</td>
# <td>5.52%
# </td></tr>
# <tr>
# <td>4</td>
# <td><a class="mw-redirect" href="/wiki/Hindi_language" title="Hindi language">Hindi</a><sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[a]</a></sup></td>
# ...

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
