# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')
print(prophet)
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'The', 'Prophet,', 'by', 'Kahlil', 'Gibran\n\nThis', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and\nmost', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions\nwhatsoever.', '', 'You', 'may', 'copy', 'it,', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms\nof', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at\nwww.gutenberg.org.', '', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States,', "you'll\nhave", 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using\nthis', 'ebook.\n\n\n\nTitle:', 'The', 'Prophet\n\nAuthor:', 'Kahlil', 'Gibran\n\nRelease', 'Date:', 'January', '1,', '2019', '[EBook', '#58585]\nLast', 'Updated:', 'January', '3,', '2018\n\n\nLanguage:', 'English\n\nCharacter', 'set', 'encoding:', 'UTF-8\n\n***', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', 'THE', 'PROPHET', '***\n\n\n\n\nProduced', 'by', 'David', 'Widger', 'from', 'page', 'images', 'generously\nprovided', 'by', 'the', 'Internet', "Archive\n\n\nTranscriber's", 'Note:', 'Page', 'numbers,', 'ie:', '{20},', 'are', 'included', 'in', 'this\nutf-8', 'text', 'file.', 'For', 'those', 'wishing', 'to', 'use', 'a', 'text', 'file', 'unencumbered\nwith', 'page', 'numbers', 'open', 'or', 'download', 'the', 'Latin-1', 'file', '58585-8.txt.\n\n\n\n\n\n\n\nTHE', 'PROPHET\n\nBy', 'Kahlil', 'Gibran\n\nNew', 'York:', 'Alfred', 'A.', 'Knopf\n\n1923\n\n_The', 'Twelve', 'Illustrations', 'In', 'This', 'Volume\nAre', 'Reproduced', 'From', 'Original', 'Drawings', 'By\nThe', 'Author_\n\n\n“His', 'power', 'came', 'from', 'some', 'great', 'reservoir\nof', 'spiritual', 'life', 'else', 'it', 'could', 'not', 'have\nbeen', 'so', 'universal', 'and', 'so', 'potent,', 'but', 'the\nmajesty', 'and', 'beauty', 'of', 'the', 'language', 'with\nwhich', 'he', 'clothed', 'it', 'were', 'all', 'his', 'own?”\n\n--Claude', 'Bragdon\n\n\nTHE', 'BOOKS', 'OF', 'KAHLIL', 'GIBRAN\n\nThe', 'Madman.', '1918', 'Twenty', 'Drawings.', '1919\nThe', 'Forerunner.', '1920', 'The', 'Prophet.', '1923\nSand', 'and', 'Foam.', '1926', 'Jesus', 'the', 'Son', 'of\nMan.', '1928', 'The', 'Forth', 'Gods.', '1931', 'The\nWanderer.', '1932', 'The', 'Garden', 'of', 'the', 'Prophet\n1933', 'Prose', 'Poems.', '1934', 'Nymphs', 'of', 'the\nValley.', '1948\n\n\n\n\nCONTENTS\n\n', '', '', '', '', '', '', '', '', '', 'The', 'Coming', 'of', 'the', 'Ship.......7\n', '', '', '', '', '', '', '', '', '', 'On', 'Love.....................15\n', '', '', '', '', '', '', '', '', '', 'On', 'Marriage.................19\n', '', '', '', '', '', '', '', '', '', 'On', 'Children.................21\n', '', '', '', '', '', '', '', '', '', 'On', 'Giving...................23\n', '', '', '', '', '', '', '', '', '', 'On', 'Eating', 'and', 'Drinking......27\n', '', '', '', '', '', '', '', '', '', 'On', 'Work.....................31\n', '', '', '', '', '', '', '', '', '', 'On', 'Joy', 'and', 'Sorrow...........33\n', '', '', '', '', '', '', '', '', '', 'On', 'Houses...................37\n', '', '', '', '', '', '', '', '', '', 'On', 'Clothes..................41\n', '', '', '', '', '', '', '', '', '', 'On', 'Buying', 'and', 'Selling.......43\n', '', '', '', '', '', '', '', '', '', 'On', 'Crime', 'and', 'Punishment.....45\n', '', '', '', '', '', '', '', '', '', 'On', 'Laws.....................51\n', '', '', '', '', '', '', '', '', '', 'On', 'Freedom..................55\n', '', '', '', '', '', '', '', '', '', 'On', 'Reason', 'and', 'Passion.......57\n', '', '', '', '', '', '', '', '', '', 'On', 'Pain.....................60\n', '', '', '', '', '', '', '', '', '', 'On', 'Self-Knowledge...........62\n', '', '', '', '', '', '', '', '', '', 'On', 'Teaching.................64\n', '', '', '', '', '', '', '', '', '', 'On', 'Friendship...............66\n', '', '', '', '', ...

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here
clnd = prophet[568:]

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here
print(clnd[1:11])
# Out:
# ['the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto', 'his']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    return(x.split('{')[0])
    # your code here

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
prophet_reference = list(map(reference, clnd))
print(prophet_reference)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto', 'his', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'in', 'the', 'city\nof', 'Orphalese', 'for', 'his', 'ship', 'that', 'was', 'to\nreturn', 'and', 'bear', 'him', 'back', 'to', 'the', 'isle', 'of\nhis', 'birth.\n\nAnd', 'in', 'the', 'twelfth', 'year,', 'on', 'the', 'seventh\nday', 'of', 'Ielool,', 'the', 'month', 'of', 'reaping,', 'he\nclimbed', 'the', 'hill', 'without', 'the', 'city', 'walls\nand', 'looked', 'seaward;', 'and', 'he', 'beheld', 'his\nship', 'coming', 'with', 'the', 'mist.\n\nThen', 'the', 'gates', 'of', 'his', 'heart', 'were', 'flung\nopen,', 'and', 'his', 'joy', 'flew', 'far', 'over', 'the', 'sea.\nAnd', 'he', 'closed', 'his', 'eyes', 'and', 'prayed', 'in', 'the\nsilences', 'of', 'his', 'soul.\n\n*****\n\nBut', 'as', 'he', 'descended', 'the', 'hill,', 'a', 'sadness\ncame', 'upon', 'him,', 'and', 'he', 'thought', 'in', 'his\nheart:\n\nHow', 'shall', 'I', 'go', 'in', 'peace', 'and', 'without\nsorrow?', 'Nay,', 'not', 'without', 'a', 'wound', 'in', 'the\nspirit', 'shall', 'I', 'leave', 'this', 'city.', '', 'the', 'days', 'of', 'pain', 'I', 'have', 'spent\nwithin', 'its', 'walls,', 'and', 'long', 'were', 'the\nnights', 'of', 'aloneness;', 'and', 'who', 'can', 'depart\nfrom', 'his', 'pain', 'and', 'his', 'aloneness', 'without\nregret?\n\nToo', 'many', 'fragments', 'of', 'the', 'spirit', 'have', 'I\nscattered', 'in', 'these', 'streets,', 'and', 'too', 'many\nare', 'the', 'children', 'of', 'my', 'longing', 'that', 'walk\nnaked', 'among', 'these', 'hills,', 'and', 'I', 'cannot\nwithdraw', 'from', 'them', 'without', 'a', 'burden', 'and\nan', 'ache.\n\nIt', 'is', 'not', 'a', 'garment', 'I', 'cast', 'off', 'this\nday,', 'but', 'a', 'skin', 'that', 'I', 'tear', 'with', 'my', 'own\nhands.\n\nNor', 'is', 'it', 'a', 'thought', 'I', 'leave', 'behind', 'me,\nbut', 'a', 'heart', 'made', 'sweet', 'with', 'hunger', 'and\nwith', 'thirst.\n\n*****\n\nYet', 'I', 'cannot', 'tarry', 'longer.\n\nThe', 'sea', 'that', 'calls', 'all', 'things', 'unto', 'her\ncalls', 'me,', 'and', 'I', 'must', 'embark.\n\nFor', 'to', 'stay,', 'though', 'the', 'hours', 'burn', 'in\nthe', 'night,', 'is', 'to', 'freeze', 'and', 'crystallize\nand', 'be', 'bound', 'in', 'a', 'mould.\n\nFain', 'would', 'I', 'take', 'with', 'me', 'all', 'that', 'is\nhere.', 'But', 'how', 'shall', 'I?\n\nA', 'voice', 'cannot', 'carry', 'the', 'tongue', 'and\n', 'lips', 'that', 'gave', 'it', 'wings.', 'Alone\nmust', 'it', 'seek', 'the', 'ether.\n\nAnd', 'alone', 'and', 'without', 'his', 'nest', 'shall', 'the\neagle', 'fly', 'across', 'the', 'sun.\n\n*****\n\nNow', 'when', 'he', 'reached', 'the', 'foot', 'of', 'the\nhill,', 'he', 'turned', 'again', 'towards', 'the', 'sea,\nand', 'he', 'saw', 'his', 'ship', 'approaching', 'the\nharbour,', 'and', 'upon', 'her', 'prow', 'the', 'mariners,\nthe', 'men', 'of', 'his', 'own', 'land.\n\nAnd', 'his', 'soul', 'cried', 'out', 'to', 'them,', 'and', 'he\nsaid:\n\nSons', 'of', 'my', 'ancient', 'mother,', 'you', 'riders', 'of\nthe', 'tides,\n\nHow', 'often', 'have', 'you', 'sailed', 'in', 'my', 'dreams.\nAnd', 'now', 'you', 'come', 'in', 'my', 'awakening,', 'which\nis', 'my', 'deeper', 'dream.\n\nReady', 'am', 'I', 'to', 'go,', 'and', 'my', 'eagerness', 'with\nsails', 'full', 'set', 'awaits', 'the', 'wind.\n\nOnly', 'another', 'breath', 'will', 'I', 'breathe', 'in\nthis', 'still', 'air,', 'only', 'another', 'loving', 'look\ncast', 'backward,\n\nAnd', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a\nseafarer', 'among', 'seafarers.', '', 'you,\nvast', 'sea,', 'sleepless', 'mother,\n\nWho', 'alone', 'are', 'peace', 'and', 'freedom', 'to', 'the\nriver', 'and', 'the', 'stream,\n\nOnly', 'another', 'winding', 'will', 'this', 'stream\nmake,', 'only', 'another', 'murmur', 'in', 'this', 'glade,\n\nAnd', 'then', 'shall', 'I', 'come', 'to', 'you,', 'a\nboundless', 'drop', 'to', 'a', 'boundless', 'ocean.\n\n*****\n\nAnd', 'as', 'he', 'walked', 'he', 's ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    return x.split('\n')[0],x.split('\n')[-1]


    # your code here

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
prophet_line = list(map(line_break, prophet_reference))
print(prophet_line)
# Out:
# [('PROPHET', '|Almustafa,'), ('the', 'the'), ('chosen', 'chosen'), ('and', 'and'), ('the', 'beloved,'), ('who', 'who'), ('was', 'was'), ('a', 'a'), ('dawn', 'dawn'), ('unto', 'unto'), ('his', 'his'), ('own', 'day,'), ('had', 'had'), ('waited', 'waited'), ('twelve', 'twelve'), ('years', 'years'), ('in', 'in'), ('the', 'the'), ('city', 'of'), ('Orphalese', 'Orphalese'), ('for', 'for'), ('his', 'his'), ('ship', 'ship'), ('that', 'that'), ('was', 'was'), ('to', 'return'), ('and', 'and'), ('bear', 'bear'), ('him', 'him'), ('back', 'back'), ('to', 'to'), ('the', 'the'), ('isle', 'isle'), ('of', 'his'), ('birth.', 'And'), ('in', 'in'), ('the', 'the'), ('twelfth', 'twelfth'), ('year,', 'year,'), ('on', 'on'), ('the', 'the'), ('seventh', 'day'), ('of', 'of'), ('Ielool,', 'Ielool,'), ('the', 'the'), ('month', 'month'), ('of', 'of'), ('reaping,', 'reaping,'), ('he', 'climbed'), ('the', 'the'), ('hill', 'hill'), ('without', 'without'), ('the', 'the'), ('city', 'city'), ('walls', 'and'), ('looked', 'looked'), ('seaward;', 'seaward;'), ('and', 'and'), ('he', 'he'), ('beheld', 'beheld'), ('his', 'ship'), ('coming', 'coming'), ('with', 'with'), ('the', 'the'), ('mist.', 'Then'), ('the', 'the'), ('gates', 'gates'), ('of', 'of'), ('his', 'his'), ('heart', 'heart'), ('were', 'were'), ('flung', 'open,'), ('and', 'and'), ('his', 'his'), ('joy', 'joy'), ('flew', 'flew'), ('far', 'far'), ('over', 'over'), ('the', 'the'), ('sea.', 'And'), ('he', 'he'), ('closed', 'closed'), ('his', 'his'), ('eyes', 'eyes'), ('and', 'and'), ('prayed', 'prayed'), ('in', 'in'), ('the', 'silences'), ('of', 'of'), ('his', 'his'), ('soul.', 'But'), ('as', 'as'), ('he', 'he'), ('descended', 'descended'), ('the', 'the'), ('hill,', 'hill,'), ('a', 'a'), ('sadness', 'came'), ('upon', 'upon'), ('him,', 'him,'), ('and', 'and'), ('he', 'he'), ('thought', 'thought'), ('in', 'in'), ('his', 'How'), ('shall', 'shall'), ('I', 'I'), ('go', 'go'), ('in', 'in'), ('peace', 'peace'), ('and', 'and'), ('without', 'sorrow?'), ('Nay,', 'Nay,'), ('not', 'not'), ('without', 'without'), ('a', 'a'), ('wound', 'wound'), ('in', 'in'), ('the', 'spirit'), ('shall', 'shall'), ('I', 'I'), ('leave', 'leave'), ('this', 'this'), ('city.', 'city.'), ('', ''), ('the', 'the'), ('days', 'days'), ('of', 'of'), ('pain', 'pain'), ('I', 'I'), ('have', 'have'), ('spent', 'within'), ('its', 'its'), ('walls,', 'walls,'), ('and', 'and'), ('long', 'long'), ('were', 'were'), ('the', 'nights'), ('of', 'of'), ('aloneness;', 'aloneness;'), ('and', 'and'), ('who', 'who'), ('can', 'can'), ('depart', 'from'), ('his', 'his'), ('pain', 'pain'), ('and', 'and'), ('his', 'his'), ('aloneness', 'aloneness'), ('without', 'Too'), ('many', 'many'), ('fragments', 'fragments'), ('of', 'of'), ('the', 'the'), ('spirit', 'spirit'), ('have', 'have'), ('I', 'scattered'), ('in', 'in'), ('these', 'these'), ('streets,', 'streets,'), ('and', 'and'), ('too', 'too'), ('many', 'are'), ('the', 'the'), ('children', 'children'), ('of', 'of'), ('my', 'my'), ('longing', 'longing'), ('that', 'that'), ('walk', 'naked'), ('among', 'among'), ('these', 'these'), ('hills,', 'hills,'), ('and', 'and'), ('I', 'I'), ('cannot', 'withdraw'), ('from', 'from'), ('them', 'them'), ('without', 'without'), ('a', 'a'), ('burden', 'burden'), ('and', 'an'), ('ache.', 'It'), ('is', 'is'), ('not', 'not'), ('a', 'a'), ('garment', 'garment'), ('I', 'I'), ('cast', 'cast'), ('off', 'off'), ('this', 'day,'), ('but', 'but'), ('a', 'a'), ('skin', 'skin'), ('that', 'that'), ('I', 'I'), ('tear', 'tear'), ('with', 'with'), ('my', 'my'), ('own', 'Nor'), ('is', 'is'), ('it', 'it'), ('a', 'a'), ('thought', 'thought'), ('I', 'I'), ('leave', 'leave'), ('behind', 'behind'), ('me,', 'but'), ('a', 'a'), ('heart', 'heart'), ('made', 'made'), ('sweet', 'sweet'), ('with', 'with'), ('hunger', 'hunger'), ('and', 'with'), ('thirst.', 'Yet'), ('I', 'I'), ('cannot', 'cannot'), ('tarry', 'tarry'), ('longer.', 'The'), ('sea', 'sea'), ('that', 'that'), ('calls', 'calls'), ('all', 'all'), ('things', 'thing ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# your code here
prophet_flat = [word for sublist in prophet_line for word in sublist]
#prophet_flat = " ".join(prophet_flat)
print(prophet_flat)
# Out:
# ['PROPHET', '|Almustafa,', 'the', 'the', 'chosen', 'chosen', 'and', 'and', 'the', 'beloved,', 'who', 'who', 'was', 'was', 'a', 'a', 'dawn', 'dawn', 'unto', 'unto', 'his', 'his', 'own', 'day,', 'had', 'had', 'waited', 'waited', 'twelve', 'twelve', 'years', 'years', 'in', 'in', 'the', 'the', 'city', 'of', 'Orphalese', 'Orphalese', 'for', 'for', 'his', 'his', 'ship', 'ship', 'that', 'that', 'was', 'was', 'to', 'return', 'and', 'and', 'bear', 'bear', 'him', 'him', 'back', 'back', 'to', 'to', 'the', 'the', 'isle', 'isle', 'of', 'his', 'birth.', 'And', 'in', 'in', 'the', 'the', 'twelfth', 'twelfth', 'year,', 'year,', 'on', 'on', 'the', 'the', 'seventh', 'day', 'of', 'of', 'Ielool,', 'Ielool,', 'the', 'the', 'month', 'month', 'of', 'of', 'reaping,', 'reaping,', 'he', 'climbed', 'the', 'the', 'hill', 'hill', 'without', 'without', 'the', 'the', 'city', 'city', 'walls', 'and', 'looked', 'looked', 'seaward;', 'seaward;', 'and', 'and', 'he', 'he', 'beheld', 'beheld', 'his', 'ship', 'coming', 'coming', 'with', 'with', 'the', 'the', 'mist.', 'Then', 'the', 'the', 'gates', 'gates', 'of', 'of', 'his', 'his', 'heart', 'heart', 'were', 'were', 'flung', 'open,', 'and', 'and', 'his', 'his', 'joy', 'joy', 'flew', 'flew', 'far', 'far', 'over', 'over', 'the', 'the', 'sea.', 'And', 'he', 'he', 'closed', 'closed', 'his', 'his', 'eyes', 'eyes', 'and', 'and', 'prayed', 'prayed', 'in', 'in', 'the', 'silences', 'of', 'of', 'his', 'his', 'soul.', 'But', 'as', 'as', 'he', 'he', 'descended', 'descended', 'the', 'the', 'hill,', 'hill,', 'a', 'a', 'sadness', 'came', 'upon', 'upon', 'him,', 'him,', 'and', 'and', 'he', 'he', 'thought', 'thought', 'in', 'in', 'his', 'How', 'shall', 'shall', 'I', 'I', 'go', 'go', 'in', 'in', 'peace', 'peace', 'and', 'and', 'without', 'sorrow?', 'Nay,', 'Nay,', 'not', 'not', 'without', 'without', 'a', 'a', 'wound', 'wound', 'in', 'in', 'the', 'spirit', 'shall', 'shall', 'I', 'I', 'leave', 'leave', 'this', 'this', 'city.', 'city.', '', '', 'the', 'the', 'days', 'days', 'of', 'of', 'pain', 'pain', 'I', 'I', 'have', 'have', 'spent', 'within', 'its', 'its', 'walls,', 'walls,', 'and', 'and', 'long', 'long', 'were', 'were', 'the', 'nights', 'of', 'of', 'aloneness;', 'aloneness;', 'and', 'and', 'who', 'who', 'can', 'can', 'depart', 'from', 'his', 'his', 'pain', 'pain', 'and', 'and', 'his', 'his', 'aloneness', 'aloneness', 'without', 'Too', 'many', 'many', 'fragments', 'fragments', 'of', 'of', 'the', 'the', 'spirit', 'spirit', 'have', 'have', 'I', 'scattered', 'in', 'in', 'these', 'these', 'streets,', 'streets,', 'and', 'and', 'too', 'too', 'many', 'are', 'the', 'the', 'children', 'children', 'of', 'of', 'my', 'my', 'longing', 'longing', 'that', 'that', 'walk', 'naked', 'among', 'among', 'these', 'these', 'hills,', 'hills,', 'and', 'and', 'I', 'I', 'cannot', 'withdraw', 'from', 'from', 'them', 'them', 'without', 'without', 'a', 'a', 'burden', 'burden', 'and', 'an', 'ache.', 'It', 'is', 'is', 'not', 'not', 'a', 'a', 'garment', 'garment', 'I', 'I', 'cast', 'cast', 'off', 'off', 'this', 'day,', 'but', 'but', 'a', 'a', 'skin', 'skin', 'that', 'that', 'I', 'I', 'tear', 'tear', 'with', 'with', 'my', 'my', 'own', 'Nor', 'is', 'is', 'it', 'it', 'a', 'a', 'thought', 'thought', 'I', 'I', 'leave', 'leave', 'behind', 'behind', 'me,', 'but', 'a', 'a', 'heart', 'heart', 'made', 'made', 'sweet', 'sweet', 'with', 'with', 'hunger', 'hunger', 'and', 'with', 'thirst.', 'Yet', 'I', 'I', 'cannot', 'cannot', 'tarry', 'tarry', 'longer.', 'The', 'sea', 'sea', 'that', 'that', 'calls', 'calls', 'all', 'all', 'things', 'things', 'unto', 'unto', 'her', 'calls', 'me,', 'me,', 'and', 'and', 'I', 'I', 'must', 'must', 'embark.', 'For', 'to', 'to', 'stay,', 'stay,', 'though', 'though', 'the', 'the', 'hours', 'hours', 'burn', 'burn', 'in', 'the', 'night,', 'night,', 'is', 'is', 'to', 'to', 'freeze', 'freeze', 'and', 'and', 'crystallize', 'and', 'be', 'be', 'bound', 'bound', 'in', 'in', 'a', 'a', 'mould.', 'Fain', 'would', 'would', 'I', 'I', 'take', 'take', 'with', 'with',  ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    word_list = ['and', 'the', 'a', 'an']
    if x not in word_list:
        return True
    elif x  in word_list:
        return False
    
#print(prophet_flat)
prophet_filter = list(filter(word_filter, prophet_line))
print(prophet_filter)
    
    # your code here
# Out:
# ['|Almustafa,', 'chosen', 'beloved,', 'who', 'was', 'dawn', 'unto', 'his', 'day,', 'had', 'waited', 'twelve', 'years', 'in', 'of', 'Orphalese', 'for', 'his', 'ship', 'that', 'was', 'return', 'bear', 'him', 'back', 'to', 'isle', 'his', 'And', 'in', 'twelfth', 'year,', 'on', 'day', 'of', 'Ielool,', 'month', 'of', 'reaping,', 'climbed', 'hill', 'without', 'city', 'looked', 'seaward;', 'he', 'beheld', 'ship', 'coming', 'with', 'Then', 'gates', 'of', 'his', 'heart', 'were', 'open,', 'his', 'joy', 'flew', 'far', 'over', 'And', 'he', 'closed', 'his', 'eyes', 'prayed', 'in', 'silences', 'of', 'his', 'But', 'as', 'he', 'descended', 'hill,', 'came', 'upon', 'him,', 'he', 'thought', 'in', 'How', 'shall', 'I', 'go', 'in', 'peace', 'sorrow?', 'Nay,', 'not', 'without', 'wound', 'in', 'spirit', 'shall', 'I', 'leave', 'this', 'city.', '', 'days', 'of', 'pain', 'I', 'have', 'within', 'its', 'walls,', 'long', 'were', 'nights', 'of', 'aloneness;', 'who', 'can', 'from', 'his', 'pain', 'his', 'aloneness', 'Too', 'many', 'fragments', 'of', 'spirit', 'have', 'scattered', 'in', 'these', 'streets,', 'too', 'are', 'children', 'of', 'my', 'longing', 'that', 'naked', 'among', 'these', 'hills,', 'I', 'withdraw', 'from', 'them', 'without', 'burden', 'It', 'is', 'not', 'garment', 'I', 'cast', 'off', 'day,', 'but', 'skin', 'that', 'I', 'tear', 'with', 'my', 'Nor', 'is', 'it', 'thought', 'I', 'leave', 'behind', 'but', 'heart', 'made', 'sweet', 'with', 'hunger', 'with', 'Yet', 'I', 'cannot', 'tarry', 'The', 'sea', 'that', 'calls', 'all', 'things', 'unto', 'calls', 'me,', 'I', 'must', 'For', 'to', 'stay,', 'though', 'hours', 'burn', 'night,', 'is', 'to', 'freeze', 'be', 'bound', 'in', 'Fain', 'would', 'I', 'take', 'with', 'me', 'all', 'that', 'here.', 'But', 'how', 'shall', 'A', 'voice', 'cannot', 'carry', 'tongue', '', 'lips', 'that', 'gave', 'it', 'wings.', 'must', 'it', 'seek', 'And', 'alone', 'without', 'his', 'nest', 'shall', 'eagle', 'fly', 'across', 'Now', 'when', 'he', 'reached', 'foot', 'of', 'hill,', 'he', 'turned', 'again', 'towards', 'he', 'saw', 'his', 'ship', 'approaching', 'harbour,', 'upon', 'her', 'prow', 'men', 'of', 'his', 'own', 'And', 'his', 'soul', 'cried', 'out', 'to', 'them,', 'Sons', 'of', 'my', 'ancient', 'mother,', 'you', 'riders', 'How', 'often', 'have', 'you', 'sailed', 'in', 'my', 'And', 'now', 'you', 'come', 'in', 'my', 'awakening,', 'is', 'my', 'deeper', 'Ready', 'am', 'I', 'to', 'go,', 'my', 'eagerness', 'sails', 'full', 'set', 'awaits', 'Only', 'another', 'breath', 'will', 'I', 'breathe', 'this', 'still', 'air,', 'only', 'another', 'loving', 'cast', 'And', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'seafarer', 'among', 'seafarers.', '', 'vast', 'sea,', 'sleepless', 'Who', 'alone', 'are', 'peace', 'freedom', 'to', 'river', 'Only', 'another', 'winding', 'will', 'this', 'make,', 'only', 'another', 'murmur', 'in', 'this', 'And', 'then', 'shall', 'I', 'come', 'to', 'you,', 'boundless', 'drop', 'to', 'boundless', 'And', 'as', 'he', 'walked', 'he', 'saw', 'from', 'afar', 'women', 'leaving', 'their', 'fields', 'vineyards', 'hastening', 'towards', 'And', 'he', 'heard', 'their', 'voices', 'calling', 'name,', 'shouting', 'from', 'field', 'to', 'telling', 'one', 'another', 'of', 'coming', 'of', 'And', 'he', 'said', 'to', 'Shall', 'day', 'of', 'parting', 'be', 'day', 'And', 'shall', 'it', 'be', 'said', 'that', 'my', 'eve', 'was', 'truth', 'my', 'And', 'what', 'shall', 'I', 'give', 'unto', 'him', 'who', 'left', 'his', 'plough', 'in', 'midfurrow,', 'or', 'him', 'who', 'has', 'stopped', 'wheel', 'of', 'winepress?', '', 'my', 'heart', 'become', 'tree', 'heavy-laden', 'with', 'fruit', 'that', 'I', 'gather', 'give', 'unto', 'And', 'shall', 'my', 'desires', 'flow', 'like', 'fountain', 'that', 'I', 'may', 'fill', 'their', 'Am', 'I', 'harp', 'that', 'hand', 'of', 'may', 'touch', 'me,', 'or', 'flute', 'that', 'his', 'may', 'pass', 'through', 'A', 'seeker', 'of', 'silences', 'am', 'I,', 'treasure', 'have', 'I', 'found', 'in', 'silences', 'that',  ...

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # your code here

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# your code here

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will connect to Ironhack's database and retrieve the data from the *pollution* database. Select the *beijing_pollution* table and retrieve its data.

# %%
# your code here

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# your code here

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    
    # your code here

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# your code here

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # your code here
