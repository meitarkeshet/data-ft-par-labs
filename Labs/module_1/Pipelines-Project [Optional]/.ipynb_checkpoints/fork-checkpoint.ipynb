# %%
import requests

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup

# %%
url = "https://www.thefork.fr/api/search/restaurants?query%5Bplace%5D%5Btype%5D=near_city&query%5Bplace%5D%5Bvalue%5D%5BcityId%5D=415144&query%5BdecorateRestaurantTags%5D%5B0%5D=4427&result%5BcurrentScreen%5D=SEARCH_RESULT_PAGE&result%5Babtest%5D%5BdisplaySnippets%5D=true&filter%5BrestaurantTagIdList%5D%5B0%5D%5Btags%5D%5B0%5D=4427&filter%5BoriginCodeList%5D%5B0%5D=THEFORKMANAGER&page%5Bnumber%5D=2&page%5Bsize%5D=25"

# %%
headers = """accept: application/json
accept-encoding: gzip, deflate, br
accept-language: fr-FR
cache-control: no-cache
content-type: application/json
cookie: tf_abtests_freshness=true; tf_ab_test=booking_funnel%3Dcontrol; CC=15102-e75; connected=false; G_ENABLED_IDPS=google; trackingId=7fb17de9-e38d-4694-977e-acf10f7f2730; _evidon_consent_cookie={"consent_date":"2020-11-26T13:49:11.189Z","consent_type":1}; ry_ry-l4f02rfr_realytics=eyJpZCI6InJ5XzRBQzc2MzIzLTYyNDAtNDNCQy04ODk4LTREMUNBNkI5N0Q3NyIsImNpZCI6bnVsbCwiZXhwIjoxNjM3OTM0NTUxNDEyLCJjcyI6bnVsbH0%3D; _gid=GA1.2.1785263786.1606398551; _hjTLDTest=1; _hjid=93a91613-4ab6-4b7d-be0b-a9e86f70b513; _hjIncludedInPageviewSample=1; _uetsid=332c86602fee11eba9e23b2c8292b73b; _uetvid=332cdfd02fee11ebb06231a0e51c1fb8; _fbp=fb.1.1606398567241.1268821727; _hjAbsoluteSessionInProgress=0; _gat=1; _dc_gtm_UA-153529018-5=1; _gat_UA-153529018-5=1; _ga_7NBMPFZNBS=GS1.1.1606401925.2.1.1606401932.0; _ga=GA1.1.792505627.1606398551; datadome=2ZnNflQjZ5jJh~vEBmBZygkTKDFNT~x_IEgOfZN9DybdaN2ksMpx2_tSv8SIEQN0bKpN_nM0VNUFyWmrup~nf3XxnkV08GJPT5IF9AFRxx
pragma: no-cache
referer: https://www.thefork.fr/search/?cityId=415144&restaurantTagId[]=4427&p=2
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
timezone: Europe/Paris
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"""

# %%
headers = dict([i.split(': ') for i in headers.split('\n')])
response = requests.get(url = url, headers = headers)
data = response.json()

# %%
import pandas as pd

# %%
data = data['data']

# %%
pd.json_normalize(data)
#data
# Out:
#                                       name servesCuisine  priceRange  \
# 0             Enza & Famiglia Pizze e Vino       Italien          34
# 1                               New Sakura      Japonais          23
# 2                         Ristorante Prima       Italien          26
# 3                     Les Bariolés de Maud      Français          22
# 4                                 L'Epopée      Français          33
# 5          Au Bon Moment Comme à la Maison      Marocain          26
# 6                                Neelkanth        Indien          22
# 7                            Les Comédiens      Pizzeria          42
# 8                                 Tassinca         Corse          15
# 9                              Jabal Liban      Libanais          20
# 10                                Dulcinea      Pizzeria          29
# 11  Enza & Famiglia Trattoria Saint Honoré       Italien          39
# 12           Vin et Marée  Voltaire-Nation      Français          49
# 13                              Yoki Sushi      Japonais          36
# 14                                   Osaka      Japonais          25
# 15                       Le Trousseau d’Or     De marché          22
# 16                       Imperial Treasure       Chinois         100
# 17                               Matsuyama      Japonais          22
# 18                                So'Chick      Français          31
# 19         Au Petit Marguery - Rive Droite      Français          44
# 20                                Alliance      Français         156
# 21                             Curry Villa        Indien          20
# 22                     Les Vignes du Liban      Libanais          28
# 23                           Mount Everest        Indien          20
# 24                             Vietnamfood    Vietnamien          30
#
#    currenciesAccepted                                       mainPhotoSrc  \
# 0                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 1                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 2                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 3                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 4                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 5                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 6                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 7                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 8                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 9                 EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 10                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 11                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 12                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 13                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 14                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 15                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 16                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 17                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 18                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 19                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 20                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 21                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 22                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 23                EUR  https://res.cloudinary.com/tf-lab/image/upload...
# 24                EUR  https://res.cloudinary.com/tf-lab/image/upload...
#
#     hasLoyaltyProgram  isBookable  isInsider  \
# 0                True        True      False
# 1               False        True      False
# 2               False        True      False
# 3                True        True      False
# 4               False        True      False
# 5               False        True      False
# 6               False        True      False
# 7               False        True      False
# 8               False        True      False
# 9               False        True      False
# 10              False        True      False
# 11              False        True      False
# 12              False        True      False
# 13              False        True      False
# 14               True        True      False
# 15               True        True      False
# 16              False        True       True
# 17              False        True      False
# 18              False        True      False
# 19               True        True      False
# 20               True        True       True
# 21              False        True      False
# 22              False        True      False
# 23              False        True      False
# 24               True        True      False
#
#                                     uuid  canBurnYums  ...  \
# 0   9ff2872a-c0f9-4102-bac4-356c597bcc28         True  ...
# 1   d820e2c0-bc49-4719-8f53-11674acdd83b        False  ...
# 2   88d430e6-de46-4eeb-b8c9-a45f3fe20dcd        False  ...
# 3   2ab9667a-b52c-4ed6-a66d-be0d7867287c        False  ...
# 4   14526dbe-0bba-4dc0-8b0a-d03ba2083200        False  ...
# 5   63f6f58d-648a-4db1-a5d0-83e57db111d3        False  ...
# 6   a350a63a-a22d-4307-9201-4e390c82a849        False  ...
# 7   73d2cc36-f59b-47fa-87bf-685c3fa2d6dc        False  ...
# 8   774bf0ef-7f3c-4d23-a6b0-e428a48ef9f7        False  ...
# 9   b75507a6-fb1b-46a5-96ac-118a8ac33479        False  ...
# 10  151141d5-6e92-4257-9d3b-70f22cb2545c        False  ...
# 11  28f8fdd8-9b2e-4c85-9ae7-b5d08b8963ef        False  ...
# 12  20a4b193-d100-4f78-847f-dac4cb8e9938        False  ...
# 13  842a8500-64e0-43f4-a9d8-132663bf3f0e        False  ...
# 14  b9f3c232-aeab-4236-bcfa-214a22941878        False  ...
# 15  0cf63f5f-99df-42bf-8144-2435da85de88        False  ...
# 16  733ee62a-47c6-42f7-9572-4f39e4bec2f8        False  ...
# 17  48344747-7bfa-4df9-a248-a377a8e16af4        False  ...
# 18  4ffc66f2-4012-455a-9662-33081047a0d8        False  ...
# 19  076d37e2-babc-476f-900d-ff515d6f1924         True  ...
# 20  781aca47-ffa1-483b-9679-aa35e34d2ad3         True  ...
# 21  50a23052-72d1-495a-b927-1a5dab14ab8e        False  ...
# 22  ef91fec5-ebdf-4bc4-b1ae-47857696f3b9        False  ...
# 23  be1ea29f-504f-405a-a95d-8a93e5cdcf4a        False  ...
# 24  3401900e-896a-4408-ad08-55414a33cec6         True  ...
#
#                   marketingOffer.title marketingOffer.type bestOffer.tagsIds  \
# 0                    -30% sur la carte                None                []
# 1                    -30% sur la carte                None                []
# 2                    -20% sur la carte                None                []
# 3                 Dîner d'automne 26 €                None               [3]
# 4                    -30% sur la carte                None                []
# 5                    -30% sur la carte                None                []
# 6                    -20% sur la carte                None                []
# 7                    -30% sur la carte                None                []
# 8                    -20% sur la carte                None                []
# 9                    -50% sur la carte                None                []
# 10                   -30% sur la carte                None                []
# 11                   -30% sur la carte                None                []
# 12                   -30% sur la carte                None                []
# 13                   -30% sur la carte                None                []
# 14                                 NaN                 NaN                []
# 15  Formule Déjeuner en semaine €15.90                None              [13]
# 16                   -20% sur la carte                None                []
# 17                   -30% sur la carte                None                []
# 18                   -30% sur la carte               Event          [12, 77]
# 19                   -30% sur la carte                None                []
# 20          Menu Instant déjeuner 55 €                None               [3]
# 21                   -50% sur la carte                None                []
# 22                   -30% sur la carte                None             [113]
# 23                   -40% sur la carte                None                []
# 24                   -50% sur la carte                None                []
#
#    bestOffer.id bestOffer.label                      bestOffer.name  \
# 0       4273329            -30%                   -30% sur la carte
# 1       4250673            -30%                   -30% sur la carte
# 2       4243657            -20%                   -20% sur la carte
# 3       4233723            MENU                Dîner d'automne 26 €
# 4       4241223            -30%                   -30% sur la carte
# 5       4210579            -30%                   -30% sur la carte
# 6       4172023            -20%                   -20% sur la carte
# 7       4161463            -30%                   -30% sur la carte
# 8       4214779            -20%                   -20% sur la carte
# 9       4158507            -50%                   -50% sur la carte
# 10      4246765            -30%                   -30% sur la carte
# 11      4209933            -30%                   -30% sur la carte
# 12      4242307            -30%                   -30% sur la carte
# 13      4158237            -30%                   -30% sur la carte
# 14      3886235                                    Stock hors promo
# 15      3643711            MENU  Formule Déjeuner en semaine €15.90
# 16      4275419            -20%                   -20% sur la carte
# 17      4063899            -30%                   -30% sur la carte
# 18      2694543            MENU                   -30% sur la carte
# 19      4271613            -30%                   -30% sur la carte
# 20      4262557            MENU          Menu Instant déjeuner 55 €
# 21      4210157            -50%                   -50% sur la carte
# 22      1978569            -30%                   -30% sur la carte
# 23      3018409            -40%                   -40% sur la carte
# 24      4198725            -50%                   -50% sur la carte
#
#    yumsDetail.isSuperYums yumsDetail.description yumsDetail.yumsCount  \
# 0                   False                    NaN                  NaN
# 1                   False                    NaN                  NaN
# 2                   False                    NaN                  NaN
# 3                    True                YUMS x2                  0.0
# 4                   False                    NaN                  NaN
# 5                   False                    NaN                  NaN
# 6                   False                    NaN                  NaN
# 7                   False                    NaN                  NaN
# 8                   False                    NaN                  NaN
# 9                   False                    NaN                  NaN
# 10                  False                    NaN                  NaN
# 11                  False                    NaN                  NaN
# 12                  False                    NaN                  NaN
# 13                  False                    NaN                  NaN
# 14                   True                YUMS x2                  0.0
# 15                   True                YUMS x2                  0.0
# 16                  False                    NaN                  NaN
# 17                  False                    NaN                  NaN
# 18                  False                    NaN                  NaN
# 19                  False                    NaN                  NaN
# 20                  False                    NaN                  NaN
# 21                  False                    NaN                  NaN
# 22                  False                    NaN                  NaN
# 23                  False                    NaN                  NaN
# 24                  False                    NaN                  NaN
#
#    marketingOffer
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
#
# [25 rows x 44 columns]

# %%
# create an empty DataFrame
df_final=pd.DataFrame()
# change the page number for each round of the loop
# append into the data frame (adds to rows in the bottom)
for i in range(1,6):
    url=f'https://www.thefork.fr/api/search/restaurants?query%5Bplace%5D%5Btype%5D=near_city&query%5Bplace%5D%5Bvalue%5D%5BcityId%5D=415144&query%5BdecorateRestaurantTags%5D%5B0%5D=4427&result%5BcurrentScreen%5D=SEARCH_RESULT_PAGE&result%5Babtest%5D%5BdisplaySnippets%5D=true&filter%5BrestaurantTagIdList%5D%5B0%5D%5Btags%5D%5B0%5D=4427&filter%5BoriginCodeList%5D%5B0%5D=THEFORKMANAGER&page%5Bnumber%5D={i}&page%5Bsize%5D=25'  
    response=r.get(url, headers=headers)
    data=response.json()
    data = data['data']
    df=pd.json_normalize(data)
    df_final=df_final.append(df)
    print('page number',i,'is done!')
# Out:
# page number 1 is done!
# page number 2 is done!
# page number 3 is done!
# page number 4 is done!
# page number 5 is done!

# %%
df_final
# Out:
#                     name servesCuisine  priceRange currenciesAccepted  \
# 0   Restaurant New Dehli        Indien          26                EUR
# 1               Visconti       Italien          48                EUR
# 2    Truffes Folies 7ème      Français          46                EUR
# 3           Le Caroubier      Marocain          39                EUR
# 4                  Tulsi        Indien          21                EUR
# ..                   ...           ...         ...                ...
# 20      Il Cuoco Galante       Italien          41                EUR
# 21                 Apéti    Végétarien          29                EUR
# 22               Habesha     Ethiopien          26                EUR
# 23               Coretta           NaN          60                EUR
# 24       Mori Venice Bar       Italien          88                EUR
#
#                                          mainPhotoSrc  hasLoyaltyProgram  \
# 0   https://res.cloudinary.com/tf-lab/image/upload...               True
# 1   https://res.cloudinary.com/tf-lab/image/upload...               True
# 2   https://res.cloudinary.com/tf-lab/image/upload...               True
# 3   https://res.cloudinary.com/tf-lab/image/upload...               True
# 4   https://res.cloudinary.com/tf-lab/image/upload...               True
# ..                                                ...                ...
# 20  https://res.cloudinary.com/tf-lab/image/upload...              False
# 21  https://res.cloudinary.com/tf-lab/image/upload...              False
# 22  https://res.cloudinary.com/tf-lab/image/upload...              False
# 23  https://res.cloudinary.com/tf-lab/image/upload...              False
# 24  https://res.cloudinary.com/tf-lab/image/upload...               True
#
#     isBookable  isInsider                                  uuid  canBurnYums  \
# 0         True      False  30cccf55-6773-4c4f-af23-dce1b0f1e9f8         True
# 1         True      False  862ed7ff-0b52-4e83-84db-c924d197add8         True
# 2         True      False  a50a170a-0f35-43be-bf60-7b31187a7dc3         True
# 3         True      False  aacc98dc-ea70-4cd6-b2c8-7b9dc193e854         True
# 4         True      False  3727abea-7a05-4d61-a308-29cbb358a64b         True
# ..         ...        ...                                   ...          ...
# 20        True       True  e3ba2fb2-cd3a-4289-bf90-a7b90c9d5539        False
# 21        True      False  fe42a6c3-ef00-497c-a9d4-404df10a4d5b        False
# 22        True       True  f3b563f1-96ef-4af9-a4fc-12184ace0341        False
# 23        True       True  f81d77e7-ce40-47ad-80f4-a53f5ceb2c1e        False
# 24        True       True  ed469022-b4b0-431f-b0f5-19b302300249         True
#
#     ... marketingOffer.title marketingOffer.type bestOffer.tagsIds  \
# 0   ...    -30% sur la carte                None                []
# 1   ...    -20% sur la carte                None                []
# 2   ...    -50% sur la carte                None                []
# 3   ...    -30% sur la carte                None                []
# 4   ...    -30% sur la carte                None                []
# ..  ...                  ...                 ...               ...
# 20  ...                  NaN                 NaN                []
# 21  ...   Formules  19€ 19 €                 NaN               [3]
# 22  ...                  NaN                 NaN                []
# 23  ...   MENU DEJEUNER 18 €                 NaN               [3]
# 24  ...                  NaN                 NaN                []
#
#    bestOffer.id bestOffer.label      bestOffer.name yumsDetail.isSuperYums  \
# 0       4158113            -30%   -30% sur la carte                   True
# 1       4250971            -20%   -20% sur la carte                   True
# 2       4250799            -50%   -50% sur la carte                  False
# 3       4229395            -30%   -30% sur la carte                   True
# 4       4188291            -30%   -30% sur la carte                  False
# ..          ...             ...                 ...                    ...
# 20      1883875                    Stock hors promo                  False
# 21      4159601            MENU  Formules  19€ 19 €                  False
# 22        72089                                                      False
# 23      4298577            MENU  MENU DEJEUNER 18 €                  False
# 24        13262                              Normal                  False
#
#    yumsDetail.description yumsDetail.yumsCount marketingOffer
# 0                 YUMS x2                  0.0            NaN
# 1                 YUMS x2                  0.0            NaN
# 2                     NaN                  NaN            NaN
# 3                 YUMS x2                  0.0            NaN
# 4                     NaN                  NaN            NaN
# ..                    ...                  ...            ...
# 20                    NaN                  NaN            NaN
# 21                    NaN                  NaN            NaN
# 22                    NaN                  NaN            NaN
# 23                    NaN                  NaN            NaN
# 24                    NaN                  NaN            NaN
#
# [125 rows x 44 columns]

# %%
# clean columns
df_dropped = df_final.drop(columns=['currenciesAccepted', 'hasLoyaltyProgram', 'isBookable',
                                   'isInsider','uuid', 'canBurnYums','highlightedTag',
                                   'marketingOffer.type','bestOffer.tagsIds','bestOffer.name',
                                   'yumsDetail.isSuperYums','yumsDetail.description',
                                   'yumsDetail.yumsCount','marketingOffer', 'snippets',
                                   'photosCarousel','id', 'geo.longitude', 'geo.latitude',
                                   'mainPhotoSrc','mainPhoto.664x374','mainPhoto.1350x759',
                                   'mainPhoto.160x120','mainPhoto.80x60','mainPhoto.92x92',
                                   'mainPhoto.184x184', 'bestOffer.id', 'mainPhoto.source',
                                   'mainPhoto.612x344', 'mainPhoto.480x270','address.country',
                                   'address.locality'])
df_dropped
# Out:
#                     name servesCuisine  priceRange            address.street  \
# 0   Restaurant New Dehli        Indien          26          4, passage Brady
# 1               Visconti       Italien          48        4, rue de l'Arcade
# 2    Truffes Folies 7ème      Français          46             37, rue Malar
# 3           Le Caroubier      Marocain          39    82, boulevard Lefebvre
# 4                  Tulsi        Indien          21  46 Rue Jacques Hillairet
# ..                   ...           ...         ...                       ...
# 20      Il Cuoco Galante       Italien          41          36 Rue Condorcet
# 21                 Apéti    Végétarien          29    72 Rue du Cherche-Midi
# 22               Habesha     Ethiopien          26          19, rue Copreaux
# 23               Coretta           NaN          60      151 bis Rue Cardinet
# 24       Mori Venice Bar       Italien          88          27, rue Vivienne
#
#    address.postalCode  aggregateRatings.thefork.ratingValue  \
# 0               75010                                   9.2
# 1               75008                                   9.2
# 2               75007                                   9.2
# 3               75015                                   9.0
# 4               75012                                   9.1
# ..                ...                                   ...
# 20              75009                                   9.5
# 21              75006                                   9.4
# 22              75015                                   9.6
# 23              75017                                   9.3
# 24              75002                                   9.5
#
#     aggregateRatings.thefork.reviewCount  \
# 0                                 1220.0
# 1                                 1756.0
# 2                                 6635.0
# 3                                 3203.0
# 4                                  790.0
# ..                                   ...
# 20                                 420.0
# 21                                 567.0
# 22                                1433.0
# 23                                 511.0
# 24                                2420.0
#
#     aggregateRatings.tripadvisor.ratingValue  \
# 0                                        4.0
# 1                                        4.0
# 2                                        4.0
# 3                                        4.0
# 4                                        4.5
# ..                                       ...
# 20                                       4.0
# 21                                       4.5
# 22                                       4.5
# 23                                       4.5
# 24                                       4.0
#
#     aggregateRatings.tripadvisor.reviewCount  \
# 0                                       75.0
# 1                                      300.0
# 2                                      384.0
# 3                                      330.0
# 4                                       25.0
# ..                                       ...
# 20                                      80.0
# 21                                      71.0
# 22                                     208.0
# 23                                     684.0
# 24                                     426.0
#
#                                     mainPhoto.240x135 marketingOffer.title  \
# 0   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 1   https://res.cloudinary.com/tf-lab/image/upload...    -20% sur la carte
# 2   https://res.cloudinary.com/tf-lab/image/upload...    -50% sur la carte
# 3   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 4   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# ..                                                ...                  ...
# 20  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 21  https://res.cloudinary.com/tf-lab/image/upload...   Formules  19€ 19 €
# 22  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 23  https://res.cloudinary.com/tf-lab/image/upload...   MENU DEJEUNER 18 €
# 24  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
#
#    bestOffer.label
# 0             -30%
# 1             -20%
# 2             -50%
# 3             -30%
# 4             -30%
# ..             ...
# 20
# 21            MENU
# 22
# 23            MENU
# 24
#
# [125 rows x 12 columns]

# %%
#df_dropped.loc[:, 'aggregateRatings.thefork.ratingValue']
ratings = df_dropped[['aggregateRatings.thefork.ratingValue', 'aggregateRatings.tripadvisor.ratingValue']] 
# format the fork rating (1-10) so that it works with the tripadvisor (1-5)
ratings['aggregateRatings.thefork.ratingValue'] /= 2
# avrage each row between the for rating and tripadvisor rating column
ratings = ratings.mean(axis=1)
#add the ratings we calculated as a column in the data_frame
df_dropped["ratings"] = ratings
df_dropped
# Out:
#                     name servesCuisine  priceRange            address.street  \
# 0   Restaurant New Dehli        Indien          26          4, passage Brady
# 1               Visconti       Italien          48        4, rue de l'Arcade
# 2    Truffes Folies 7ème      Français          46             37, rue Malar
# 3           Le Caroubier      Marocain          39    82, boulevard Lefebvre
# 4                  Tulsi        Indien          21  46 Rue Jacques Hillairet
# ..                   ...           ...         ...                       ...
# 20      Il Cuoco Galante       Italien          41          36 Rue Condorcet
# 21                 Apéti    Végétarien          29    72 Rue du Cherche-Midi
# 22               Habesha     Ethiopien          26          19, rue Copreaux
# 23               Coretta           NaN          60      151 bis Rue Cardinet
# 24       Mori Venice Bar       Italien          88          27, rue Vivienne
#
#    address.postalCode  aggregateRatings.thefork.ratingValue  \
# 0               75010                                   9.2
# 1               75008                                   9.2
# 2               75007                                   9.2
# 3               75015                                   9.0
# 4               75012                                   9.1
# ..                ...                                   ...
# 20              75009                                   9.5
# 21              75006                                   9.4
# 22              75015                                   9.6
# 23              75017                                   9.3
# 24              75002                                   9.5
#
#     aggregateRatings.thefork.reviewCount  \
# 0                                 1220.0
# 1                                 1756.0
# 2                                 6635.0
# 3                                 3203.0
# 4                                  790.0
# ..                                   ...
# 20                                 420.0
# 21                                 567.0
# 22                                1433.0
# 23                                 511.0
# 24                                2420.0
#
#     aggregateRatings.tripadvisor.ratingValue  \
# 0                                        4.0
# 1                                        4.0
# 2                                        4.0
# 3                                        4.0
# 4                                        4.5
# ..                                       ...
# 20                                       4.0
# 21                                       4.5
# 22                                       4.5
# 23                                       4.5
# 24                                       4.0
#
#     aggregateRatings.tripadvisor.reviewCount  \
# 0                                       75.0
# 1                                      300.0
# 2                                      384.0
# 3                                      330.0
# 4                                       25.0
# ..                                       ...
# 20                                      80.0
# 21                                      71.0
# 22                                     208.0
# 23                                     684.0
# 24                                     426.0
#
#                                     mainPhoto.240x135 marketingOffer.title  \
# 0   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 1   https://res.cloudinary.com/tf-lab/image/upload...    -20% sur la carte
# 2   https://res.cloudinary.com/tf-lab/image/upload...    -50% sur la carte
# 3   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 4   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# ..                                                ...                  ...
# 20  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 21  https://res.cloudinary.com/tf-lab/image/upload...   Formules  19€ 19 €
# 22  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 23  https://res.cloudinary.com/tf-lab/image/upload...   MENU DEJEUNER 18 €
# 24  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
#
#    bestOffer.label  ratings
# 0             -30%    4.300
# 1             -20%    4.300
# 2             -50%    4.300
# 3             -30%    4.250
# 4             -30%    4.525
# ..             ...      ...
# 20                    4.375
# 21            MENU    4.600
# 22                    4.650
# 23            MENU    4.575
# 24                    4.375
#
# [125 rows x 13 columns]

# %%
# drop the now not-relevent ratings
cln_dropped = df_dropped.drop(columns=['aggregateRatings.thefork.ratingValue',
                                      'aggregateRatings.thefork.reviewCount',
                                      'aggregateRatings.tripadvisor.ratingValue',
                                      'aggregateRatings.tripadvisor.reviewCount'])
# extract the quartier from the code postal
quartier = cln_dropped['address.postalCode']
quartier = [(int(i) % 100) for i in list(quartier)]
# add to data frame
cln_dropped["quartier"] = quartier
# drop the now unused postal code
cln_dropped = cln_dropped.drop(columns=["address.postalCode"])
cln_dropped
# Out:
#                     name servesCuisine  priceRange            address.street  \
# 0   Restaurant New Dehli        Indien          26          4, passage Brady
# 1               Visconti       Italien          48        4, rue de l'Arcade
# 2    Truffes Folies 7ème      Français          46             37, rue Malar
# 3           Le Caroubier      Marocain          39    82, boulevard Lefebvre
# 4                  Tulsi        Indien          21  46 Rue Jacques Hillairet
# ..                   ...           ...         ...                       ...
# 20      Il Cuoco Galante       Italien          41          36 Rue Condorcet
# 21                 Apéti    Végétarien          29    72 Rue du Cherche-Midi
# 22               Habesha     Ethiopien          26          19, rue Copreaux
# 23               Coretta           NaN          60      151 bis Rue Cardinet
# 24       Mori Venice Bar       Italien          88          27, rue Vivienne
#
#                                     mainPhoto.240x135 marketingOffer.title  \
# 0   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 1   https://res.cloudinary.com/tf-lab/image/upload...    -20% sur la carte
# 2   https://res.cloudinary.com/tf-lab/image/upload...    -50% sur la carte
# 3   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 4   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# ..                                                ...                  ...
# 20  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 21  https://res.cloudinary.com/tf-lab/image/upload...   Formules  19€ 19 €
# 22  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 23  https://res.cloudinary.com/tf-lab/image/upload...   MENU DEJEUNER 18 €
# 24  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
#
#    bestOffer.label  ratings  quartier
# 0             -30%    4.300        10
# 1             -20%    4.300         8
# 2             -50%    4.300         7
# 3             -30%    4.250        15
# 4             -30%    4.525        12
# ..             ...      ...       ...
# 20                    4.375         9
# 21            MENU    4.600         6
# 22                    4.650        15
# 23            MENU    4.575        17
# 24                    4.375         2
#
# [125 rows x 9 columns]

# %%
cln_dropped
# calculate the "offer"'s' effect on the "priceRange"
# create lists 
pricerange = list(cln_dropped['priceRange'])
offer = list(cln_dropped['bestOffer.label'])
# turn empty values ("") and "MENU" into 0
# clean the rest
offer = list([
        i.replace("", "0") if i == ''
        else
        (i.replace("%", "").
         replace("-", "").
         replace("MENU", "0")
         )
         for i in offer])
# turn into ints
offer = [int(i) for i in offer]

#reduce offer from price range

afterReduc = []

#notice the rounding

for i in list(range(len(offer))):
    afterReduc.append(round((pricerange[i] - ((offer[i] / 100)*pricerange[i]))))

# add the column to a new dataFrame
    
byPrice = cln_dropped
byPrice["priceRAfterReduc"] = afterReduc
byPrice
# Out:
#                     name servesCuisine  priceRange            address.street  \
# 0   Restaurant New Dehli        Indien          26          4, passage Brady
# 1               Visconti       Italien          48        4, rue de l'Arcade
# 2    Truffes Folies 7ème      Français          46             37, rue Malar
# 3           Le Caroubier      Marocain          39    82, boulevard Lefebvre
# 4                  Tulsi        Indien          21  46 Rue Jacques Hillairet
# ..                   ...           ...         ...                       ...
# 20      Il Cuoco Galante       Italien          41          36 Rue Condorcet
# 21                 Apéti    Végétarien          29    72 Rue du Cherche-Midi
# 22               Habesha     Ethiopien          26          19, rue Copreaux
# 23               Coretta           NaN          60      151 bis Rue Cardinet
# 24       Mori Venice Bar       Italien          88          27, rue Vivienne
#
#                                     mainPhoto.240x135 marketingOffer.title  \
# 0   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 1   https://res.cloudinary.com/tf-lab/image/upload...    -20% sur la carte
# 2   https://res.cloudinary.com/tf-lab/image/upload...    -50% sur la carte
# 3   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# 4   https://res.cloudinary.com/tf-lab/image/upload...    -30% sur la carte
# ..                                                ...                  ...
# 20  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 21  https://res.cloudinary.com/tf-lab/image/upload...   Formules  19€ 19 €
# 22  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
# 23  https://res.cloudinary.com/tf-lab/image/upload...   MENU DEJEUNER 18 €
# 24  https://res.cloudinary.com/tf-lab/image/upload...                  NaN
#
#    bestOffer.label  ratings  quartier  priceRAfterReduc
# 0             -30%    4.300        10                18
# 1             -20%    4.300         8                38
# 2             -50%    4.300         7                23
# 3             -30%    4.250        15                27
# 4             -30%    4.525        12                15
# ..             ...      ...       ...               ...
# 20                    4.375         9                41
# 21            MENU    4.600         6                29
# 22                    4.650        15                26
# 23            MENU    4.575        17                60
# 24                    4.375         2                88
#
# [125 rows x 10 columns]

# %%
# drop the price columns 
byPrice = byPrice.drop(columns=["bestOffer.label", "priceRange"])

# reorder 
byPrice = byPrice.reindex(columns= ['name', 'servesCuisine', 'priceRAfterReduc',
                                    'ratings','quartier','address.street',
                                    'marketingOffer.title','mainPhoto.240x135'
                                    ])
byPrice
# Out:
#                     name servesCuisine  priceRAfterReduc  ratings  quartier  \
# 0   Restaurant New Dehli        Indien                18    4.300        10
# 1               Visconti       Italien                38    4.300         8
# 2    Truffes Folies 7ème      Français                23    4.300         7
# 3           Le Caroubier      Marocain                27    4.250        15
# 4                  Tulsi        Indien                15    4.525        12
# ..                   ...           ...               ...      ...       ...
# 20      Il Cuoco Galante       Italien                41    4.375         9
# 21                 Apéti    Végétarien                29    4.600         6
# 22               Habesha     Ethiopien                26    4.650        15
# 23               Coretta           NaN                60    4.575        17
# 24       Mori Venice Bar       Italien                88    4.375         2
#
#               address.street marketingOffer.title  \
# 0           4, passage Brady    -30% sur la carte
# 1         4, rue de l'Arcade    -20% sur la carte
# 2              37, rue Malar    -50% sur la carte
# 3     82, boulevard Lefebvre    -30% sur la carte
# 4   46 Rue Jacques Hillairet    -30% sur la carte
# ..                       ...                  ...
# 20          36 Rue Condorcet                  NaN
# 21    72 Rue du Cherche-Midi   Formules  19€ 19 €
# 22          19, rue Copreaux                  NaN
# 23      151 bis Rue Cardinet   MENU DEJEUNER 18 €
# 24          27, rue Vivienne                  NaN
#
#                                     mainPhoto.240x135
# 0   https://res.cloudinary.com/tf-lab/image/upload...
# 1   https://res.cloudinary.com/tf-lab/image/upload...
# 2   https://res.cloudinary.com/tf-lab/image/upload...
# 3   https://res.cloudinary.com/tf-lab/image/upload...
# 4   https://res.cloudinary.com/tf-lab/image/upload...
# ..                                                ...
# 20  https://res.cloudinary.com/tf-lab/image/upload...
# 21  https://res.cloudinary.com/tf-lab/image/upload...
# 22  https://res.cloudinary.com/tf-lab/image/upload...
# 23  https://res.cloudinary.com/tf-lab/image/upload...
# 24  https://res.cloudinary.com/tf-lab/image/upload...
#
# [125 rows x 8 columns]

# %%
FIELDS = ['name', 'priceRange', 'servesCuisine']
def clean_data(data):
    table = pd.DataFrame()
    for i in range(len(data) - 1):
        df = pd.json_normalize(data[i + 1])
        df = df[FIELDS]
        table = table.append(df)
    return table

cleand = clean_data(data)
cleand.shape
# problematic : 'address' , 'aggregateRatings', bestOffer
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-435-cc682b8e69e3> in <module>
#       8     return table
#       9
# ---> 10 cleand = clean_data(data)
#      11 cleand.shape
#      12 # problematic : 'address' , 'aggregateRatings', bestOffer
#
# <ipython-input-435-cc682b8e69e3> in clean_data(data)
#       4     for i in range(len(data) - 1):
#       5         df = pd.json_normalize(data[i + 1])
# ----> 6         df = df[FIELDS]
#       7         table = table.append(df)
#       8     return table
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['servesCuisine'] not in index"

# %%
addresse = [resto.get("address") for resto in data]
ad_street = [resto.get("street") for resto in addresse]
ad_quartier = [resto.get("postalCode")[-2:] for resto in addresse]

# %%
aggregateRatings = [resto.get("aggregateRatings") for resto in data]
aggregateRatings = [resto.get("thefork") for resto in aggregateRatings]
aggregateRatings = [sum(resto.values()) for resto in aggregateRatings]

# %%
bestOffer = [resto.get("bestOffer") for resto in data]
bestOffer = [resto.get("label").
             replace("%", "").
             replace("-", "")
             for resto in bestOffer]
len(bestOffer)
bestOffer
# Out:
# ['30',
#  '30',
#  '20',
#  'MENU',
#  '30',
#  '30',
#  '20',
#  '30',
#  '20',
#  '50',
#  '30',
#  '30',
#  '30',
#  '',
#  'MENU',
#  '20',
#  '30',
#  'MENU',
#  '30',
#  'MENU',
#  '50',
#  '30',
#  '40',
#  '50',
#  '20']

# %%
#cleand['bestOffer'] = bestOffer 
#len(aggregateRatings)
#cleand['aggregateRatings'] = aggregateRatings
# Out:
# [30,
#  221.7,
#  262.1,
#  594.3,
#  987.8,
#  605.5,
#  311.8,
#  1905.5,
#  14,
#  49.9,
#  1492.4,
#  44.4,
#  12406.7,
#  12.7,
#  380.6,
#  199.6,
#  47.6,
#  1358.1,
#  4563.7,
#  556.8,
#  498.3,
#  3684.4,
#  2603.3,
#  365.3,
#  1357.4]

# %%
cleand
# Out:
#                                      name  priceRange servesCuisine
# 0                              New Sakura          23      Japonais
# 0                        Ristorante Prima          26       Italien
# 0                    Les Bariolés de Maud          22      Français
# 0                                L'Epopée          33      Français
# 0         Au Bon Moment Comme à la Maison          26      Marocain
# 0                               Neelkanth          22        Indien
# 0                           Les Comédiens          42      Pizzeria
# 0                                Tassinca          15         Corse
# 0                             Jabal Liban          20      Libanais
# 0                                Dulcinea          29      Pizzeria
# 0  Enza & Famiglia Trattoria Saint Honoré          39       Italien
# 0           Vin et Marée  Voltaire-Nation          49      Français
# 0                                   Osaka          25      Japonais
# 0                       Le Trousseau d’Or          22     De marché
# 0                       Imperial Treasure         100       Chinois
# 0                               Matsuyama          22      Japonais
# 0                                So'Chick          31      Français
# 0         Au Petit Marguery - Rive Droite          44      Français
# 0                                Alliance         156      Français
# 0                             Curry Villa          20        Indien
# 0                     Les Vignes du Liban          28      Libanais
# 0                           Mount Everest          20        Indien
# 0                             Vietnamfood          30    Vietnamien
# 0                      Palais de Krishnaa          25        Indien
